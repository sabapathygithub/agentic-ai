# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace
from IPython.display import display, Markdown

# %%
load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name="FinanceAdvisor", instructions="Provide financial advice to users based on their queries.", model="gpt-4o-mini")

# %%
with trace("Tell me a finance advice"):
    result = await Runner().run(agent, "What is the best way to save for retirement?")

# %% [markdown]
# ### Now go and look at the trace
#
# https://platform.openai.com/traces

# %%
display(Markdown(f"### Agent Response:\n\n{result.final_output}"))
# Out:
# ### Agent Response:
#
# Saving for retirement is an important financial goal, and there are several effective strategies to consider:
#
# 1. **Start Early**: The earlier you begin saving, the more time your money has to grow due to compound interest.
#
# 2. **Employer-Sponsored Retirement Plans**: If your employer offers a 401(k) plan, consider contributing enough to get any matching contributions, as this is essentially free money.
#
# 3. **Individual Retirement Accounts (IRAs)**: Depending on your income and tax situation, consider contributing to a Traditional IRA or a Roth IRA. Traditional IRAs may provide tax deductions, while Roth IRAs allow for tax-free withdrawals in retirement.
#
# 4. **Automate Contributions**: Set up automatic transfers to your retirement accounts to ensure that saving becomes a regular habit.
#
# 5. **Diversify Investments**: Allocate your retirement savings across different asset classes (stocks, bonds, mutual funds) to spread risk and increase the potential for growth.
#
# 6. **Monitor and Rebalance**: Regularly review your investment portfolio and adjust your asset allocation based on age, risk tolerance, and market conditions.
#
# 7. **Minimize Fees**: Look for low-cost investment options like index funds or ETFs to maximize your returns over time. High fees can erode your savings significantly.
#
# 8. **Increase Contributions Over Time**: As you receive raises or bonuses, consider increasing your contributions. A good rule of thumb is to raise your contribution rate by 1% each year.
#
# 9. **Emergency Fund**: Maintain an emergency fund to avoid withdrawing from retirement accounts in case of unexpected expenses, which may incur penalties.
#
# 10. **Consult a Financial Advisor**: If you're uncertain about how to allocate your savings or choose investments, working with a financial planner can help tailor a strategy that suits your needs.
#
# By following these strategies and regularly assessing your retirement savings plan, you can build a secure financial future for your retirement years.
