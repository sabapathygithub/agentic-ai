# %% [markdown]
# # OpenAI API Example
#
# ### Step 1: Importing the necessary packages

# %%
from openai import OpenAI
from dotenv import load_dotenv

# %% [markdown]
# ### Step 2: Load the API key from .env file

# %%
load_dotenv(override=True)
# Out:
# True

# %%
openai_client = OpenAI()
question = "Do you know about Agentic AI?"
messages = [    
    {"role": "user", "content": question}
]
response = openai_client.chat.completions.create(
    model="gpt-4o-mini", 
    messages=messages
)
print(response.choices[0].message.content)
# Out:
# Yes, Agentic AI refers to artificial intelligence systems that can perform tasks autonomously or with a level of decision-making capability that resembles agency. This concept often involves the ability to understand and process information, make decisions based on that information, and take actions towards achieving specific goals without constant human oversight.
#
# Key characteristics of Agentic AI may include:
#
# 1. **Autonomy**: The ability to operate independently in a given environment.
# 2. **Decision-making**: The capability to analyze situations and make choices based on data and predefined objectives.
# 3. **Learning**: A capacity for continuous improvement through learning from experiences and data.
# 4. **Adaptability**: The ability to adjust actions based on changes in the environment or task requirements.
#
# Agentic AI can be utilized in various applications, such as robotics, autonomous vehicles, personal assistants, and more complex systems like AI in gaming or simulations.
#
# The development of Agentic AI raises important ethical and safety considerations, particularly regarding accountability, transparency, and the potential impact on jobs and society. Researchers and policymakers are actively discussing these issues as the technology evolves.

# %%
from IPython.display import Markdown, display
display(Markdown(f"**Q:** {question}\n\n**A:** {response.choices[0].message.content}"))
# Out:
# **Q:** Do you know about Agentic AI?
#
# **A:** Yes, Agentic AI refers to artificial intelligence systems that can perform tasks autonomously or with a level of decision-making capability that resembles agency. This concept often involves the ability to understand and process information, make decisions based on that information, and take actions towards achieving specific goals without constant human oversight.
#
# Key characteristics of Agentic AI may include:
#
# 1. **Autonomy**: The ability to operate independently in a given environment.
# 2. **Decision-making**: The capability to analyze situations and make choices based on data and predefined objectives.
# 3. **Learning**: A capacity for continuous improvement through learning from experiences and data.
# 4. **Adaptability**: The ability to adjust actions based on changes in the environment or task requirements.
#
# Agentic AI can be utilized in various applications, such as robotics, autonomous vehicles, personal assistants, and more complex systems like AI in gaming or simulations.
#
# The development of Agentic AI raises important ethical and safety considerations, particularly regarding accountability, transparency, and the potential impact on jobs and society. Researchers and policymakers are actively discussing these issues as the technology evolves.
